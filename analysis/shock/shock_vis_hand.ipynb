# %%
import pyvista as pv
import h5py
import numpy as np

h5_file = 'trajectory.h5'

with h5py.File(h5_file, 'r') as f:
    data = f['data'][0]

print(data.shape)

pv.plot(data)

# %%
pl = pv.Plotter()
pl.add_mesh(data)
pl.show()
